# %%
import pickle
import pandas as pd

# %%
with open('w2v.p', 'rb') as f:
    df = pickle.load(f)

# %%
df
# Out:
#                         victim-total                     victim-con  \
# 0                 (damage, 피해, 0.85)          (attacker, 가해자, 0.88)
# 1                 (party, 당사자, 0.75)             (damage, 피해, 0.88)
# 2              (attacker, 가해자, 0.75)             (party, 당사자, 0.85)
# 3             (hesitation, 주저, 0.73)           (Kkotbaem, 꽃뱀, 0.82)
# 4                 (appeal, 호소, 0.71)             (appeal, 호소, 0.79)
# 5                    (aid, 조력자, 0.7)             (regret, 반성, 0.79)
# 6                    (pain, 고통, 0.7)  (False accusation, 무고죄, 0.79)
# 7       (Burden of proof, 입증책임, 0.7)       (Keep in mind, 유념, 0.78)
# 8      (False accusation, 무고죄, 0.69)           (Innocent, 무고, 0.78)
# 9      (severe punishment, 엄벌, 0.69)            (Witness, 증언, 0.78)
# 10              (Innocent, 무고, 0.69)              (honor, 명예, 0.77)
# 11               (verity, 진실성, 0.69)  (Burden of proof, 입증책임, 0.77)
# 12                   (Sue, 고소, 0.68)               (pain, 고통, 0.77)
# ...
